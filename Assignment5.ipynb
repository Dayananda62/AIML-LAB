# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('headbrain.csv')
X=df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

mean_x=np.mean(X)
mean_y=np.mean(Y)
n=len(X)

numer=0
denom=0
for i in range(n):
    numer+=(X[i]-mean_x)*(Y[i]-mean_y)
    denom+=(X[i]-mean_x)**2
m=numer/denom
c=mean_y-(m*mean_x)
print("m=",m)
print("c=",c)

#%matplotlib inline
y = m * X + c
#print(y)
plt.plot(X, y, color='blue', label='Regression Line')
plt.scatter(X, Y, color='green', label='Scatter data')
plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()

rmse = 0
for i in range(n):
    y_pred = c + m * X[i]
    rmse += (Y[i] - y_pred) ** 2
    
rmse = np.sqrt(rmse/n)
print("Root Mean Square Error is",rmse)

ss_tot = 0
ss_res = 0
for i in range(n):
    y_pred = c + m * X[i]
    ss_tot += (Y[i] - mean_y) ** 2
    ss_res += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_res/ss_tot)
print("R^2 Score",r2)

X=int(input("Enter value for Headsize(1200):"))
print("Predicted Brain weight is:",m*X+c)
# Out:
# m= 0.26342933948939945
# c= 325.57342104944223
# Root Mean Square Error is 72.1206213783709
# R^2 Score 0.6393117199570003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 50
#      47 r2 = 1 - (ss_res/ss_tot)
#      48 print("R^2 Score",r2)
# ---> 50 X=int(input("Enter value for Headsize(1200):"))
#      51 print("Predicted Brain weight is:",m*X+c)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('hprice.csv')
X=df['total_sqft_int'].values
Y = df['price'].values

mean_x=np.mean(X)
mean_y=np.mean(Y)
n=len(X)

numer=0
denom=0
for i in range(n):
    numer+=(X[i]-mean_x)*(Y[i]-mean_y)
    denom+=(X[i]-mean_x)**2
m=numer/denom
c=mean_y-(m*mean_x)
print("m=",m)
print("c=",c)

#%matplotlib inline
y = m * X + c
#print(y)
plt.plot(X, y, color='blue', label='Regression Line')
plt.scatter(X, Y, c='green', label='Scatter data')
plt.xlabel('Total Square Feet')
plt.ylabel('Price')
plt.legend()
plt.show()

rmse = 0
for i in range(n):
    y_pred = c + m * X[i]
    rmse += (Y[i] - y_pred) ** 2
    
rmse = np.sqrt(rmse/n)
print("Root Mean Square Error is",rmse)

ss_tot = 0
ss_res = 0
for i in range(n):
    y_pred = c + m * X[i]
    ss_tot += (Y[i] - mean_y) ** 2
    ss_res += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_res/ss_tot)
print("R^2 Score",r2)

flag=1
while(flag==1):
    X=int(input("Enter value for Toatal Square Feet:"))
    print("Predicted Price is:",m*X+c)
    flag=int(input("Do you want to continue?(1/0):"))
# Out:
# m= 0.10145818551992836
# c= -53.675710323968744
# Root Mean Square Error is 70.02176909392135
# R^2 Score 0.6367323019884783

# %%
# New values for total_sqft_int
new_data_single = pd.DataFrame({'total_sqft_int': [1500]})  # Replace 1500 with your desired value
new_data_multiple = pd.DataFrame({'total_sqft_int': [1500, 2000, 2500]})  # Example values

# Predict the price for one new value
predicted_price_single = model.predict(new_data_single)
print(f'Predicted price for total_sqft_int of 1500: {predicted_price_single[0]}')

# Predict the price for three new values
predicted_prices_multiple = model.predict(new_data_multiple)
print('Predicted prices for total_sqft_int of [1500, 2000, 2500]:')
for sqft, price in zip(new_data_multiple['total_sqft_int'], predicted_prices_multiple):
    print(f'Total Sqft: {sqft}, Predicted Price: {price}')

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load the dataset from a CSV file (update the file path accordingly)
data = pd.read_csv('hprice.csv')

# Define independent (X) and dependent (y) variables
X = data['total_sqft_int'].values.reshape(-1, 1)  # Independent variable: total square footage
y = data['price'].values  # Dependent variable: house price

# Split the data into training (75%) and testing (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create and train a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Create an array of new total_sqft_int values to predict prices for
new_total_sqft_int = np.array([1200, 1500, 1800, 2000])

# Reshape the array to match the input format of the model (1D array)
new_total_sqft_int = new_total_sqft_int.reshape(-1, 1)

# Predict the prices for the new values
new_prices = model.predict(new_total_sqft_int)

# Plot the graph
plt.scatter(X_test, y_test, color='blue', label='Actual Data')  # Scatter plot of actual data points
plt.plot(X_test, model.predict(X_test), color='red', linewidth=2, label='Regression Line')  # Regression line for test data
plt.scatter(new_total_sqft_int, new_prices, color='green', marker='o', label='Predicted Prices')  # Predicted prices for new values
plt.xlabel('Total Square Feet (int)')
plt.ylabel('Price')
plt.title('Linear Regression - Price vs. Total Square Feet')
plt.legend()
plt.show()  # Display the plot

# Print the predicted prices for new values
for i, sqft in enumerate(new_total_sqft_int):
    print(f"Predicted price for {sqft} sq. ft.: ${new_prices[i]:.2f}")
# Out:
# Predicted price for [1200] sq. ft.: $68.57
# Predicted price for [1500] sq. ft.: $97.70
# Predicted price for [1800] sq. ft.: $126.82
# Predicted price for [2000] sq. ft.: $146.24

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example dataset
# X: Features, y: Prices
X = np.array([1, 2, 3, 4,5])  # Example features
y = np.array([1200, 1500, 1800, 2000,2400])  # Example prices

# Manually split data into 75% training and 25% testing
train_size = int(len(X) * 0.75)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Calculate slope (m) and intercept (b) manually
n = len(X_train)
mean_x = np.mean(X_train)
mean_y = np.mean(y_train)

# Slope (m)
numerator = np.sum((X_train - mean_x) * (y_train - mean_y))
denominator = np.sum((X_train - mean_x) ** 2)
m = numerator / denominator

# Intercept (b)
b = mean_y - m * mean_x

# Function to predict prices manually
def predict(X_values):
    return m * X_values + b

# Predict for a single new price
new_price_single = np.array([6])  # New input
predicted_price_single = predict(new_price_single)

print(f"Predicted price for {new_price_single[0]}: {predicted_price_single[0]}")

# Predict for three new prices
new_prices_multiple = np.array([6,7, 8, 9,10])  # New inputs
predicted_prices_multiple = predict(new_prices_multiple)

print(f"Predicted prices for {new_prices_multiple}: {predicted_prices_multiple}")

# Plot the graph
plt.scatter(X, y, color='blue', label='Original Data')  # Original data
plt.plot(X, predict(X), color='red', label='Fitted Line')  # Fitted line
plt.scatter(new_prices_multiple, predicted_prices_multiple, color='green', label='Predictions')  # Predictions
plt.xlabel("Feature")
plt.ylabel("Price")
plt.legend()
plt.title("Price Prediction (Manual Linear Regression)")
plt.show()
# Out:
# Predicted price for 6: 2700.0
# Predicted prices for [ 6  7  8  9 10]: [2700. 3000. 3300. 3600. 3900.]
